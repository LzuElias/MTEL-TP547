# %%
# !pip install numpy
# !pip install matplotlib

# %%
import numpy as np


N = 100000  # Tamanho da amostra
num_rand = np.random.geometric(p, size=N)

# Parâmetros
p = 20 / (30 + 20)  # Probabilidade de obter uma bola preta

# Geração das variáveis aleatórias geométricas
amostras_geomet = num_rand

# Contagem de casos onde a 6ª bola retirada com reposição é a primeira bola preta
count = np.sum(amostras_geomet == 6)

# Probabilidade de que a 6ª bola retirada com reposição seja a primeira bola preta
prob = (count/N)*100
print("Probabilidade de que a 6ª bola retirada com reposição seja a primeira bola preta:", prob)
# Out:
# Probabilidade de que a 6ª bola retirada com reposição seja a primeira bola preta: 3.057
